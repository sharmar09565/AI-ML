# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5.0])
print(arr.dtype)

arr1 = np.array([5+6j])
arr2 = np.array([2+5j])
print(arr1-arr2)
print(arr2.dtype)

arr3 = np.array(["hi",{1,2,3}, 5.32])
print(arr3.dtype)
# Out:
# float64
# [3.+1.j]
# complex128
# object
