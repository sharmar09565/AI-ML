# %%
import pandas as pd

# %%
info = {
    "Name": ["Raj","Puja","Rahul"],
    "CGPA": [8.4,8.1,8.6]
}

df = pd.DataFrame(info)     # dataframes are like 2D arr(labelled, means start from a idx/Sno.) or table

print(df)
# Out:
#     Name  CGPA
# 0    Raj   8.4
# 1   Puja   8.1
# 2  Rahul   8.6

# %%
df
# Out:
#     Name  CGPA
# 0    Raj   8.4
# 1   Puja   8.1
# 2  Rahul   8.6
