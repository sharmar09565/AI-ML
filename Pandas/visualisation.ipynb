# %%
import pandas as pd

# %%
df = pd.read_csv('employee_data.csv')

# df['Age'].hist()        # hist() means histogram, shows distribution(frequency) of data

df.plot(kind='scatter', x='Age', y='Salary')    # shows the relationship or trend of data
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>
