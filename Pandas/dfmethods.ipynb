# %%
import pandas as pd

# %%
# df = pd.read_csv("employee_data.csv")

# print(df, type(df))

df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
# methods

# df.head(3)       # gives starting rows. if para is not passed then it returns starting 5 data
# # df.head()  #gives starting 5 data

# df.tail(2)        # gives ending rows. if para is not passed then it returns starting 5 data
# df.tail()       # gives ending 5 data

# df.sample()        # gives a random data
# df.sample(3)       # gives 3 random data

# df.info()        # gives summary about data

df.shape

df.describe()       # it gives you the value like count, mean, max, min, sd etc
df.columns

df.nunique()    # how much unique data are present
# Out:
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64

# %%
#  AQI data set
df = pd.read_csv('globalAirQuality.csv')

df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
# After importing the we performs df methods to understand the data
df.head()
df.tail()

df.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
# selecting data

# accessing columns
df['city']
df[['city', 'aqi']]

# selecting rows- it can be label based(use loc) and index based(use iloc)

df.loc[0]
df.loc[0:2]     # here starting and ending both idx are included

df.iloc[2]
df.iloc[0:2]    # here ending idx is not included

# cells -  accessing both row and col
df.loc[0,'aqi']     # row-0 and col-'aqi
df.loc[0:2,['city','aqi']]

df.columns
# df.iloc[0:2,['city','aqi']]       #gives error bcz iloc takes numeric val as i stands for idx here
df.iloc[0:3,[2,11]]
df.iloc[0:3,1:5]

# cell - access single value

df.at[0,'city']
df.iat[0,2]

# cities = df['city']     # this is view
# cities[0] = 'Mumbai'    # so change in this affects the original data also so we use copy() method to create a copy of the original data to keep it protected


cities = df['city'].copy()      # now copy is created
cities[0] = 'Mumbai'    # does not change the original data
# Out:
# np.int64(108)
